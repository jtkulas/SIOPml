# %%
import pandas as pd
import numpy as np
# Filter rows with column
dataset=pd.read_csv("Womens Clothing E-Commerce Reviews.csv")
dataset
# Out:
#        index  Clothing ID  Age  \
# 0          0          767   33
# 1          1         1080   34
# 2          2         1077   60
# 3          3         1049   50
# 4          4          847   47
# ...      ...          ...  ...
# 23481  23481         1104   34
# 23482  23482          862   48
# 23483  23483         1104   31
# 23484  23484         1084   28
# 23485  23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# ...

# %%
# !pip install autokeras
import autokeras as ak
# Preparing the data for autokeras
data=dataset
X = data["Review Text"]
y = data["Rating"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
X_train_ak = np.array(data.loc[X_train.index, 'Review Text'])
y_train_ak = np.array(data.loc[X_train.index, 'Rating'])
X_test_ak = np.array(data.loc[X_test.index, 'Review Text'])
y_test_ak = np.array(data.loc[X_test.index, 'Rating'])
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 11
#       9 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
#      10 X_train_ak = np.array(data.loc[X_train.index, 'Review Text'])
# ---> 11 y_train_ak = int(np.array(data.loc[X_train.index, 'Rating']))
#      12 X_test_ak = np.array(data.loc[X_test.index, 'Review Text'])
#      13 y_test_ak = int(np.array(data.loc[X_test.index, 'Rating']))
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
y_train_ak
# Out:
# array([1, 5, 3, ..., 3, 3, 5], dtype=int64)

# %%
# Create the model
import tensorflow as tf
#X_train_ak = tf.convert_to_tensor(X_train_ak)
#X_test_ak = tf.convert_to_tensor(X_test_ak)
#y_train_ak = tf.convert_to_tensor(y_train_ak)
#y_test_ak = tf.convert_to_tensor(X_test_ak)
keras = ak.TextRegressor(overwrite=True, max_trials=3)
# Fit the training dataset
keras.fit(X_train_ak, y_train_ak, epochs=30, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 9
#       7 keras = ak.TextRegressor(overwrite=True, max_trials=3)
#       8 # Fit the training dataset
# ----> 9 keras.fit(X_train_ak, y_train_ak, epochs=30, validation_split=0.2)
#
# File ~\anaconda3\lib\site-packages\autokeras\tasks\text.py:292, in TextRegressor.fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     235 def fit(
#     236     self,
#     237     x=None,
#    (...)
#     243     **kwargs
#     244 ):
#     245     """Search for the best model and hyperparameters for the AutoModel.
#     246
#     247     It will search for the best model based on the performances on
#    (...)
#     290             validation loss values and validation metrics values (if applicable).
#     291     """
# --> 292     history = super().fit(
#     293         x=x,
# ...
